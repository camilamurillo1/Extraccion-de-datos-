# %% [markdown]
# <a href="https://colab.research.google.com/github/camilamurillo1/Extraccion-de-datos-/blob/main/Actividad1_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %% [markdown]
# CARGA DE ARCHIVO XLSX

# %%
#Convertir en dataframe
df=pd.read_excel("DatosFacturación.xlsx")
df
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414    2465.0      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415    3926.0      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416    3926.0      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417    3926.0      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418    6813.0      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...       ...    ...       ...                     ...        ...
# 10890  F40306    8842.0      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307    6218.0      E       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892  F40308    5926.0      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309     361.0      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310    3011.0      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
#Verificamos información del DataFrame
df.info()

# %%
#Imprimo los primeros 5 registro del dataframe
df.head(3)
# Out:
#   CVE_DOC    CVE_CLPV STATUS  CVE_VEND           FECHAELAB  FECHA_DOC  \
# 0  F29414        2465      C       1.0 2019-09-03 08:58:42 2019-09-03
# 1  F29415        3926      C       1.0 2019-09-03 09:55:14 2019-09-03
# 2  F29416        3926      C       1.0 2019-09-03 13:25:33 2019-09-03
#
#              FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# 0  2019-09-03 00:00:00 2019-09-18    2019-09-04   3980.0      0.0        0
# 1  2019-09-03 00:00:00 2019-10-03    2019-09-03   1550.0      0.0        0
# 2  2019-09-03 00:00:00 2019-10-03    2019-09-03   1550.0      0.0        0

# %%
filtro1=df[(df["CVE_CLPV"] > 1000) & (df["CVE_CLPV"] < 2000)]
filtro1
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 18     F29432    1965.0      C       2.0 2019-09-05 11:05:04.000 2019-09-05
# 22     F29436    1965.0      C       2.0 2019-09-06 12:01:36.000 2019-09-06
# 65     F29479    1240.0      E       2.0 2019-09-11 18:38:45.000 2019-09-11
# 71     F29485    1965.0      C       2.0 2019-09-12 12:14:28.000 2019-09-12
# 72     F29486    1965.0      E       2.0 2019-09-12 12:25:52.000 2019-09-12
# ...       ...       ...    ...       ...                     ...        ...
# 10821  F40237    1757.0      E       2.0 2023-02-24 15:18:17.570 2023-02-24
# 10839  F40255    1583.0      E       2.0 2023-02-28 09:15:45.753 2023-02-28
# 10845  F40261    1786.0      E       2.0 2023-02-28 11:15:32.527 2023-02-28
# 10871  F40287    1453.0      E       1.0 2023-03-01 12:58:23.397 2023-03-01
# 10876  F40292    1082.0      E       6.0 2023-03-02 11:00:54.770 2023-03-02
#
# ...

# %%
filtro1.to_csv("Filtro1.csv")

from google.colab import files 
files.download("Filtro1.csv")

# %%
#Filtro not "&"
filtro2=df[~(df["CVE_VEND"] == "5") & ~(df["CVE_VEND"] == "4")]
filtro2
# Out:
#       CVE_DOC    CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414        2465      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415        3926      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416        3926      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417        3926      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418        6813      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...         ...    ...       ...                     ...        ...
# 10890  F40306        8842      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307        6218      E       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892  F40308        5926      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309         361      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310        3011      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
filtro2.to_csv("Filtro2.csv")

from google.colab import files 
files.download("Filtro2.csv")

# %%
#Filtro o "|"
filtro4=df[(df["CAN_TOT"] < 5951.7) | (df["STATUS"] == "E")]
filtro4
# Out:
#       CVE_DOC    CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414        2465      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415        3926      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416        3926      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417        3926      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418        6813      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...         ...    ...       ...                     ...        ...
# 10890  F40306        8842      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307        6218      E       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892  F40308        5926      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309         361      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310        3011      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
filtro4.to_csv("Filtro4.csv")

from google.colab import files 
files.download("Filtro4.csv")

# %%
#Filtro de filas vs columnas 
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-398e8110-a2cd-4e2d-905b-b8a1b10c4dcb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-398e8110-a2cd-4e2d-905b-b8a1b10c4dcb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1= pd.read_excel("DatosFacturación.xlsx", index_col=3) #indicas que columna quieres que sea como indice 
df1
# Out:
#          CVE_DOC  CVE_CLPV STATUS               FECHAELAB  FECHA_DOC  \
# CVE_VEND
# 1.0       F29414    2465.0      C 2019-09-03 08:58:42.000 2019-09-03
# 1.0       F29415    3926.0      C 2019-09-03 09:55:14.000 2019-09-03
# 1.0       F29416    3926.0      C 2019-09-03 13:25:33.000 2019-09-03
# 1.0       F29417    3926.0      C 2019-09-03 13:33:23.000 2019-09-03
# 2.0       F29418    6813.0      C 2019-09-03 14:23:45.000 2019-09-03
# ...          ...       ...    ...                     ...        ...
# 2.0       F40306    8842.0      E 2023-03-06 16:09:39.013 2023-03-06
# 2.0       F40307    6218.0      E 2023-03-06 16:38:42.933 2023-03-06
# 2.0       F40308    5926.0      E 2023-03-06 17:02:33.390 2023-03-06
# 2.0       F40309     361.0      E 2023-03-07 12:43:49.567 2023-03-07
# 2.0       F40310    3011.0      E 2023-03-07 12:45:58.407 2023-03-07
#
#                     FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  \
# CVE_VEND
# ...

# %%
#Filtro por columnas

filtro5=df1.iloc[ 1:11 , [0,5,6,8]]  #Columnas no consecutivas 
filtro5
# Out:
#                     CVE_DOC            FECHA_ENT  FECHA_VEN   CAN_TOT
# FECHAELAB
# 2019-09-03 09:55:14  F29415  2019-09-03 00:00:00 2019-10-03  1550.000
# 2019-09-03 13:25:33  F29416  2019-09-03 00:00:00 2019-10-03  1550.000
# 2019-09-03 13:33:23  F29417  2019-09-03 00:00:00 2019-10-03  1550.000
# 2019-09-03 14:23:45  F29418  2019-09-03 00:00:00 2019-09-03  2435.440
# 2019-09-04 09:15:12  F29419  2019-09-04 00:00:00 2019-09-19  3979.998
# 2019-09-04 10:53:53  F29420  2019-09-04 00:00:00 2019-09-04   402.590
# 2019-09-04 10:56:44  F29421  2019-09-04 00:00:00 2019-09-04   402.590
# 2019-09-04 11:14:44  F29422  2019-09-02 00:00:00 2019-09-04  1606.740
# 2019-09-04 12:23:05  F29423  2019-09-02 00:00:00 2019-09-04  1144.430
# 2019-09-04 12:36:15  F29424  2019-09-03 00:00:00 2019-09-04   462.310

# %%
filtro5.to_csv("Filtro5.csv")

from google.colab import files 
files.download("Filtro5.csv")

# %%
#Filtro por filas

filtro6= df.iloc[7001:7099,: ]           #Filas consecutivas, : es para que te den todas las columnas 
 
filtro6
# Out:
#      CVE_DOC    CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 7001  F36417        5271      E       3.0 2021-10-15 08:40:29.183 2021-10-15
# 7002  F36418        5746      E       2.0 2021-10-15 08:51:03.463 2021-10-15
# 7003  F36419        2163      E       3.0 2021-10-15 08:56:23.280 2021-10-15
# 7004  F36420        1429      E       1.0 2021-10-15 09:01:08.393 2021-10-15
# 7005  F36421        5039      E       1.0 2021-10-15 09:07:07.103 2021-10-15
# ...      ...         ...    ...       ...                     ...        ...
# 7094  F36510        4480      E       2.0 2021-10-27 13:01:57.527 2021-10-27
# 7095  F36511        4480      E       2.0 2021-10-27 13:07:43.223 2021-10-27
# 7096  F36512        8186      E       2.0 2021-10-27 13:22:23.980 2021-10-27
# 7097  F36513        4403      E       2.0 2021-10-27 13:35:40.677 2021-10-27
# 7098  F36514        5589      E       2.0 2021-10-27 14:02:54.630 2021-10-27
#
# ...

# %%
filtro6.to_csv("Filtro6.csv")

from google.colab import files 
files.download("Filtro6.csv")

# %%
df2=df.set_index("CVE_VEND")
filtro7=df2.loc[[1,2],["FECHAELAB"]]
filtro7
# Out:
#                        FECHAELAB
# CVE_VEND
# 1.0      2019-09-03 08:58:42.000
# 1.0      2019-09-03 09:55:14.000
# 1.0      2019-09-03 13:25:33.000
# 1.0      2019-09-03 13:33:23.000
# 1.0      2019-09-04 09:15:12.000
# ...                          ...
# 2.0      2023-03-06 16:09:39.013
# 2.0      2023-03-06 16:38:42.933
# 2.0      2023-03-06 17:02:33.390
# 2.0      2023-03-07 12:43:49.567
# 2.0      2023-03-07 12:45:58.407
#
# [8665 rows x 1 columns]

# %%
filtro7.to_csv("Filtro7.csv")

from google.colab import files 
files.download("Filtro7.csv")
